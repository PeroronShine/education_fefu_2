# %% [markdown]
# Задание:
# Написать программу на языке программирования Python, реализующую:
# 1) Предварительную обработку текста, включающую:
# • Перевод текста в нижний регистр
# • Удаление знаков препинания
# • Удаление стоп-слов
# • Удаление лишних символов
# • Стемминг и лемматизацию
# 2) Преобразование текста в мешок слов
# 3) Преобразование текста в N-граммы, где N=2,4
#
# Замечание!
# Желательно провести предварительную обработку текста с использованием библиотеки NLTK.

# %%
# !pip install nltk pymystem3 razdel

import re
from razdel import tokenize as razdel_tokenize
from pymystem3 import Mystem
from nltk.stem.snowball import SnowballStemmer
from collections import Counter

mystem = Mystem()
stemmer = SnowballStemmer("russian")

stop_words = set([
    'и', 'в', 'на', 'с', 'не', 'он', 'как', 'что', 'а', 'но', 'только', 'один', 'под', 'из', 'по', 'у', 'за', 'о',
    'то', 'этот', 'всё', 'к', 'же', 'ни', 'где', 'когда', 'был', 'было', 'мог', 'свой', 'ещё', 'так', 'для', 'или',
    'чтобы', 'бы', 'ли', 'там', 'всегда', 'между', 'об', 'их', 'мы', 'вы', 'ты', 'меня', 'его', 'её', 'них', 'ним',
    'над', 'при', 'до', 'от', 'через', 'без', 'всех', 'весь', 'все', 'всю', 'всем', 'всеми', 'будет', 'будут'
])

text = """
На краю дороги стоял дуб. Вероятно, в десять раз старше берёз, составлявших лес, он был в десять раз толще и в два раза выше каждой берёзы. Это был огромный в два обхвата дуб с обломанными, давно видно, суками и с обломанной корой, заросшей старыми болячками. С огромными своими неуклюжими, несимметрично-растопыренными, корявыми руками и пальцами, он старым, сердитым и презрительным уродом стоял между улыбающимися берёзами. Только он один не хотел подчиняться обаянию весны и не хотел видеть ни весны, ни солнца.
«Весна, и любовь, и счастие!» – как будто говорил этот дуб, – «и как не надоест вам всё один и тот же глупый и бессмысленный обман. Всё одно и то же, и всё обман! Нет ни весны, ни солнца, ни счастия. Вон смотрите, сидят задавленные мёртвые ели, всегда одинакие, и вон и я растопырил свои обломанные, ободранные пальцы, где ни выросли они – из спины, из боков; как выросли – так и стою, и не верю вашим надеждам и обманам».
Князь Андрей несколько раз оглянулся на этот дуб, проезжая по лесу, как будто он чего-то ждал от него. Цветы и трава были и под дубом, но он всё так же, хмурясь, неподвижно, уродливо и упорно, стоял посреди их. «Да, он прав, тысячу раз прав этот дуб, думал князь Андрей, пускай другие, молодые, вновь поддаются на этот обман, а мы знаем жизнь, – наша жизнь кончена!» Целый новый ряд мыслей безнадёжных, но грустно-приятных в связи с этим дубом, возник в душе князя Андрея. Во время этого путешествия он как будто вновь обдумал всю свою жизнь, и пришёл к тому же прежнему успокоительному и безнадёжному заключению, что ему начинать ничего было не надо, что он должен доживать свою жизнь, не делая зла, не тревожась и ничего не желая.
"""

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = [token.text for token in razdel_tokenize(text)]
    tokens = [word for word in tokens if word not in stop_words]

    lemmatized_tokens = [mystem.lemmatize(word)[0] for word in tokens]

    stemmed_tokens = [stemmer.stem(word) for word in tokens]

    return lemmatized_tokens, stemmed_tokens

def bag_of_words(tokens):
    return Counter(tokens)

def generate_ngrams(tokens, n):
    return [' '.join(tokens[i:i + n]) for i in range(len(tokens) - n + 1)]

def main():
    lemmatized_tokens, stemmed_tokens = preprocess_text(text)

    print("\nЛемматизированные токены:", lemmatized_tokens)
    print("\nСтемминговые токены:", stemmed_tokens)

    bow_lemmatized = bag_of_words(lemmatized_tokens)
    bow_stemmed = bag_of_words(stemmed_tokens)

    print("\nМешок слов (лемматизированный):", bow_lemmatized)
    print("\nМешок слов (стемминговый):", bow_stemmed)

    bigrams_lemmatized = generate_ngrams(lemmatized_tokens, 2)
    bigrams_stemmed = generate_ngrams(stemmed_tokens, 2)

    fourgrams_lemmatized = generate_ngrams(lemmatized_tokens, 4)
    fourgrams_stemmed = generate_ngrams(stemmed_tokens, 4)

    print("\nБиграммы (лемматизированные):", bigrams_lemmatized)
    print("\nБиграммы (стемминговые):", bigrams_stemmed)

    print("\nЧетырехиграммы (лемматизированные):", fourgrams_lemmatized)
    print("\nЧетырехиграммы (стемминговые):", fourgrams_stemmed)

if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: pymystem3 in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: razdel in /usr/local/lib/python3.11/dist-packages (0.5.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pymystem3) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pymystem3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pymystem3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pymystem3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pymystem3) (2025.1.31)
#
# Лемматизированные токены: ['край', 'дорога', 'стоять', 'дуб', 'вероятно', 'десять', 'раз', 'старый', 'береза', 'составлять', 'лес', 'десять', 'раз', 'толстый', 'два', 'раз', 'высоко', 'каждый', 'береза', 'это', 'огромный', 'два', 'обхват', 'дуб', 'обломать', 'давно', 'видно', 'сук', 'обломать', 'кора', 'зарастать', 'старый', 'болячка', 'огромный', 'свой', 'неуклюжий', 'несимметричнорастопыривать', 'корявый', 'рука', 'палец', 'старый', 'сердитый', 'презрительный', 'урод', 'стоять', 'улыбаться', 'береза', 'хотеть', 'подчиняться', 'обаяние', 'весна', 'хотеть', 'видеть', 'весна', 'солнце', 'весна', 'любовь', 'счастие', 'будто', 'говорить', 'дуб', 'надоедать', 'вы', 'тот', 'глупый', 'бессмысленный', 'обман', 'один', 'обман', 'нет', 'весна', 'солнце', 'счастие', 'вон', 'смотреть', 'сидеть', 'задавливать', 'мертвый', 'есть', 'одинакий', 'вон', 'я', 'растопыривать', 'свой', 'обломать', 'обдирать', 'палец', 'вырастать', 'они', 'спина', 'бок', 'вырастать', 'стоять', 'верить', 'ваш', 'надежда', 'обман', 'князь', 'андрей', 'несколько', 'раз', 'оглянуться', 'дуб', 'проезжать', 'лес', 'будто', 'чегото', 'ждать', 'он', 'цветок', 'трава', 'быть', 'дуб', 'хмуриться', 'неподвижно', 'уродливый', 'упорно', 'стоять', 'посреди', 'да', 'правый', 'тысяча', 'раз', 'правый', 'дуб', 'думать', 'князь', 'андрей', 'пускай', 'другой', 'молодой', 'вновь', 'поддаваться', 'обман', 'знать', 'жизнь', 'наш', 'жизнь', 'кончать', 'целый', 'новый', 'ряд', 'мысль', 'безнадежный', 'грустноприятный', 'связь', 'это', 'дуб', 'возникать', 'душа', 'князь', 'андрей', 'во', 'время', 'это', 'путешествие', 'будто', 'вновь', 'обдумывать', 'свой', 'жизнь', 'приходить', 'то', 'прежний', 'успокоительный', 'безнадежный', 'заключение', 'он', 'начинать', 'ничего', 'надо', 'должный', 'доживать', 'свой', 'жизнь', 'делать', 'зло', 'тревожиться', 'ничего', 'желать']
#
# Стемминговые токены: ['кра', 'дорог', 'стоя', 'дуб', 'вероятн', 'деся', 'раз', 'старш', 'берез', 'составля', 'лес', 'деся', 'раз', 'толщ', 'два', 'раз', 'выш', 'кажд', 'берез', 'эт', 'огромн', 'два', 'обхват', 'дуб', 'облома', 'давн', 'видн', 'сук', 'облома', 'кор', 'заросш', 'стар', 'болячк', 'огромн', 'сво', 'неуклюж', 'несимметричнорастопырен', 'коряв', 'рук', 'пальц', 'стар', 'сердит', 'презрительн', 'урод', 'стоя', 'улыба', 'берез', 'хотел', 'подчиня', 'обаян', 'весн', 'хотел', 'видет', 'весн', 'солнц', 'весн', 'любов', 'счаст', 'будт', 'говор', 'дуб', 'надоест', 'вам', 'тот', 'глуп', 'бессмыслен', 'обма', 'одн', 'обма', 'нет', 'весн', 'солнц', 'счаст', 'вон', 'смотр', 'сид', 'задавлен', 'мертв', 'ел', 'одинак', 'вон', 'я', 'растопыр', 'сво', 'облома', 'ободра', 'пальц', 'выросл', 'он', 'спин', 'бок', 'выросл', 'сто', 'вер', 'ваш', 'надежд', 'обман', 'княз', 'андр', 'нескольк', 'раз', 'оглянул', 'дуб', 'проезж', 'лес', 'будт', 'чегот', 'ждал', 'нег', 'цвет', 'трав', 'был', 'дуб', 'хмур', 'неподвижн', 'уродлив', 'упорн', 'стоя', 'посред', 'да', 'прав', 'тысяч', 'раз', 'прав', 'дуб', 'дума', 'княз', 'андр', 'пуска', 'друг', 'молод', 'внов', 'подда', 'обма', 'зна', 'жизн', 'наш', 'жизн', 'конч', 'цел', 'нов', 'ряд', 'мысл', 'безнадежн', 'грустноприятн', 'связ', 'эт', 'дуб', 'возник', 'душ', 'княз', 'андре', 'во', 'врем', 'эт', 'путешеств', 'будт', 'внов', 'обдума', 'сво', 'жизн', 'пришел', 'том', 'прежн', 'успокоительн', 'безнадежн', 'заключен', 'ем', 'начина', 'нич', 'над', 'долж', 'дожива', 'сво', 'жизн', 'дел', 'зла', 'тревож', 'нич', 'жел']
#
# Мешок слов (лемматизированный): Counter({'дуб': 7, 'раз': 5, 'стоять': 4, 'свой': 4, 'весна': 4, 'обман': 4, 'жизнь': 4, 'старый': 3, 'береза': 3, 'это': 3, 'обломать': 3, 'будто': 3, 'князь': 3, 'андрей': 3, 'десять': 2, 'лес': 2, 'два': 2, 'огромный': 2, 'палец': 2, 'хотеть': 2, 'солнце': 2, 'счастие': 2, 'вон': 2, 'вырастать': 2, 'он': 2, 'правый': 2, 'вновь': 2, 'безнадежный': 2, 'ничего': 2, 'край': 1, 'дорога': 1, 'вероятно': 1, 'составлять': 1, 'толстый': 1, 'высоко': 1, 'каждый': 1, 'обхват': 1, 'давно': 1, 'видно': 1, 'сук': 1, 'кора': 1, 'зарастать': 1, 'болячка': 1, 'неуклюжий': 1, 'несимметричнорастопыривать': 1, 'корявый': 1, 'рука': 1, 'сердитый': 1, 'презрительный': 1, 'урод': 1, 'улыбаться': 1, 'подчиняться': 1, 'обаяние': 1, 'видеть': 1, 'любовь': 1, 'говорить': 1, 'надоедать': 1, 'вы': 1, 'тот': 1, 'глупый': 1, 'бессмысленный': 1, 'один': 1, 'нет': 1, 'смотреть': 1, 'сидеть': 1, 'задавливать': 1, 'мертвый': 1, 'есть': 1, 'одинакий': 1, 'я': 1, 'растопыривать': 1, 'обдирать': 1, 'они': 1, 'спина': 1, 'бок': 1, 'верить': 1, 'ваш': 1, 'надежда': 1, 'несколько': 1, 'оглянуться': 1, 'проезжать': 1, 'чегото': 1, 'ждать': 1, 'цветок': 1, 'трава': 1, 'быть': 1, 'хмуриться': 1, 'неподвижно': 1, 'уродливый': 1, 'упорно': 1, 'посреди': 1, 'да': 1, 'тысяча': 1, 'думать': 1, 'пускай': 1, 'другой': 1, 'молодой': 1, 'поддаваться': 1, 'знать': 1, 'наш': 1, 'кончать': 1, 'целый': 1, 'новый': 1, 'ряд': 1, 'мысль': 1, 'грустноприятный': 1, 'связь': 1, 'возникать': 1, 'душа': 1, 'во': 1, 'время': 1, 'путешествие': 1, 'обдумывать': 1, 'приходить': 1, 'то': 1, 'прежний': 1, 'успокоительный': 1, 'заключение': 1, 'начинать': 1, 'надо': 1, 'должный': 1, 'доживать': 1, 'делать': 1, 'зло': 1, 'тревожиться': 1, 'желать': 1})
#
# Мешок слов (стемминговый): Counter({'дуб': 7, 'раз': 5, 'сво': 4, 'весн': 4, 'жизн': 4, 'стоя': 3, 'берез': 3, 'эт': 3, 'облома': 3, 'будт': 3, 'обма': 3, 'княз': 3, 'деся': 2, 'лес': 2, 'два': 2, 'огромн': 2, 'стар': 2, 'пальц': 2, 'хотел': 2, 'солнц': 2, 'счаст': 2, 'вон': 2, 'выросл': 2, 'андр': 2, 'прав': 2, 'внов': 2, 'безнадежн': 2, 'нич': 2, 'кра': 1, 'дорог': 1, 'вероятн': 1, 'старш': 1, 'составля': 1, 'толщ': 1, 'выш': 1, 'кажд': 1, 'обхват': 1, 'давн': 1, 'видн': 1, 'сук': 1, 'кор': 1, 'заросш': 1, 'болячк': 1, 'неуклюж': 1, 'несимметричнорастопырен': 1, 'коряв': 1, 'рук': 1, 'сердит': 1, 'презрительн': 1, 'урод': 1, 'улыба': 1, 'подчиня': 1, 'обаян': 1, 'видет': 1, 'любов': 1, 'говор': 1, 'надоест': 1, 'вам': 1, 'тот': 1, 'глуп': 1, 'бессмыслен': 1, 'одн': 1, 'нет': 1, 'смотр': 1, 'сид': 1, 'задавлен': 1, 'мертв': 1, 'ел': 1, 'одинак': 1, 'я': 1, 'растопыр': 1, 'ободра': 1, 'он': 1, 'спин': 1, 'бок': 1, 'сто': 1, 'вер': 1, 'ваш': 1, 'надежд': 1, 'обман': 1, 'нескольк': 1, 'оглянул': 1, 'проезж': 1, 'чегот': 1, 'ждал': 1, 'нег': 1, 'цвет': 1, 'трав': 1, 'был': 1, 'хмур': 1, 'неподвижн': 1, 'уродлив': 1, 'упорн': 1, 'посред': 1, 'да': 1, 'тысяч': 1, 'дума': 1, 'пуска': 1, 'друг': 1, 'молод': 1, 'подда': 1, 'зна': 1, 'наш': 1, 'конч': 1, 'цел': 1, 'нов': 1, 'ряд': 1, 'мысл': 1, 'грустноприятн': 1, 'связ': 1, 'возник': 1, 'душ': 1, 'андре': 1, 'во': 1, 'врем': 1, 'путешеств': 1, 'обдума': 1, 'пришел': 1, 'том': 1, 'прежн': 1, 'успокоительн': 1, 'заключен': 1, 'ем': 1, 'начина': 1, 'над': 1, 'долж': 1, 'дожива': 1, 'дел': 1, 'зла': 1, 'тревож': 1, 'жел': 1})
#
# Биграммы (лемматизированные): ['край дорога', 'дорога стоять', 'стоять дуб', 'дуб вероятно', 'вероятно десять', 'десять раз', 'раз старый', 'старый береза', 'береза составлять', 'составлять лес', 'лес десять', 'десять раз', 'раз толстый', 'толстый два', 'два раз', 'раз высоко', 'высоко каждый', 'каждый береза', 'береза это', 'это огромный', 'огромный два', 'два обхват', 'обхват дуб', 'дуб обломать', 'обломать давно', 'давно видно', 'видно сук', 'сук обломать', 'обломать кора', 'кора зарастать', 'зарастать старый', 'старый болячка', 'болячка огромный', 'огромный свой', 'свой неуклюжий', 'неуклюжий несимметричнорастопыривать', 'несимметричнорастопыривать корявый', 'корявый рука', 'рука палец', 'палец старый', 'старый сердитый', 'сердитый презрительный', 'презрительный урод', 'урод стоять', 'стоять улыбаться', 'улыбаться береза', 'береза хотеть', 'хотеть подчиняться', 'подчиняться обаяние', 'обаяние весна', 'весна хотеть', 'хотеть видеть', 'видеть весна', 'весна солнце', 'солнце весна', 'весна любовь', 'любовь счастие', 'счастие будто', 'будто говорить', 'говорить дуб', 'дуб надоедать', 'надоедать вы', 'вы тот', 'тот глупый', 'глупый бессмысленный', 'бессмысленный обман', 'обман один', 'один обман', 'обман нет', 'нет весна', 'весна солнце', 'солнце счастие', 'счастие вон', 'вон смотреть', 'смотреть сидеть', 'сидеть задавливать', 'задавливать мертвый', 'мертвый есть', 'есть одинакий', 'одинакий вон', 'вон я', 'я растопыривать', 'растопыривать свой', 'свой обломать', 'обломать обдирать', 'обдирать палец', 'палец вырастать', 'вырастать они', 'они спина', 'спина бок', 'бок вырастать', 'вырастать стоять', 'стоять верить', 'верить ваш', 'ваш надежда', 'надежда обман', 'обман князь', 'князь андрей', 'андрей несколько', 'несколько раз', 'раз оглянуться', 'оглянуться дуб', 'дуб проезжать', 'проезжать лес', 'лес будто', 'будто чегото', 'чегото ждать', 'ждать он', 'он цветок', 'цветок трава', 'трава быть', 'быть дуб', 'дуб хмуриться', 'хмуриться неподвижно', 'неподвижно уродливый', 'уродливый упорно', 'упорно стоять', 'стоять посреди', 'посреди да', 'да правый', 'правый тысяча', 'тысяча раз', 'раз правый', 'правый дуб', 'дуб думать', 'думать князь', 'князь андрей', 'андрей пускай', 'пускай другой', 'другой молодой', 'молодой вновь', 'вновь поддаваться', 'поддаваться обман', 'обман знать', 'знать жизнь', 'жизнь наш', 'наш жизнь', 'жизнь кончать', 'кончать целый', 'целый новый', 'новый ряд', 'ряд мысль', 'мысль безнадежный', 'безнадежный грустноприятный', 'грустноприятный связь', 'связь это', 'это дуб', 'дуб возникать', 'возникать душа', 'душа князь', 'князь андрей', 'андрей во', 'во время', 'время это', 'это путешествие', 'путешествие будто', 'будто вновь', 'вновь обдумывать', 'обдумывать свой', 'свой жизнь', 'жизнь приходить', 'приходить то', 'то прежний', 'прежний успокоительный', 'успокоительный безнадежный', 'безнадежный заключение', 'заключение он', 'он начинать', 'начинать ничего', 'ничего надо', 'надо должный', 'должный доживать', 'доживать свой', 'свой жизнь', 'жизнь делать', 'делать зло', 'зло тревожиться', 'тревожиться ничего', 'ничего желать']
#
# Биграммы (стемминговые): ['кра дорог', 'дорог стоя', 'стоя дуб', 'дуб вероятн', 'вероятн деся', 'деся раз', 'раз старш', 'старш берез', 'берез составля', 'составля лес', 'лес деся', 'деся раз', 'раз толщ', 'толщ два', 'два раз', 'раз выш', 'выш кажд', 'кажд берез', 'берез эт', 'эт огромн', 'огромн два', 'два обхват', 'обхват дуб', 'дуб облома', 'облома давн', 'давн видн', 'видн сук', 'сук облома', 'облома кор', 'кор заросш', 'заросш стар', 'стар болячк', 'болячк огромн', 'огромн сво', 'сво неуклюж', 'неуклюж несимметричнорастопырен', 'несимметричнорастопырен коряв', 'коряв рук', 'рук пальц', 'пальц стар', 'стар сердит', 'сердит презрительн', 'презрительн урод', 'урод стоя', 'стоя улыба', 'улыба берез', 'берез хотел', 'хотел подчиня', 'подчиня обаян', 'обаян весн', 'весн хотел', 'хотел видет', 'видет весн', 'весн солнц', 'солнц весн', 'весн любов', 'любов счаст', 'счаст будт', 'будт говор', 'говор дуб', 'дуб надоест', 'надоест вам', 'вам тот', 'тот глуп', 'глуп бессмыслен', 'бессмыслен обма', 'обма одн', 'одн обма', 'обма нет', 'нет весн', 'весн солнц', 'солнц счаст', 'счаст вон', 'вон смотр', 'смотр сид', 'сид задавлен', 'задавлен мертв', 'мертв ел', 'ел одинак', 'одинак вон', 'вон я', 'я растопыр', 'растопыр сво', 'сво облома', 'облома ободра', 'ободра пальц', 'пальц выросл', 'выросл он', 'он спин', 'спин бок', 'бок выросл', 'выросл сто', 'сто вер', 'вер ваш', 'ваш надежд', 'надежд обман', 'обман княз', 'княз андр', 'андр нескольк', 'нескольк раз', 'раз оглянул', 'оглянул дуб', 'дуб проезж', 'проезж лес', 'лес будт', 'будт чегот', 'чегот ждал', 'ждал нег', 'нег цвет', 'цвет трав', 'трав был', 'был дуб', 'дуб хмур', 'хмур неподвижн', 'неподвижн уродлив', 'уродлив упорн', 'упорн стоя', 'стоя посред', 'посред да', 'да прав', 'прав тысяч', 'тысяч раз', 'раз прав', 'прав дуб', 'дуб дума', 'дума княз', 'княз андр', 'андр пуска', 'пуска друг', 'друг молод', 'молод внов', 'внов подда', 'подда обма', 'обма зна', 'зна жизн', 'жизн наш', 'наш жизн', 'жизн конч', 'конч цел', 'цел нов', 'нов ряд', 'ряд мысл', 'мысл безнадежн', 'безнадежн грустноприятн', 'грустноприятн связ', 'связ эт', 'эт дуб', 'дуб возник', 'возник душ', 'душ княз', 'княз андре', 'андре во', 'во врем', 'врем эт', 'эт путешеств', 'путешеств будт', 'будт внов', 'внов обдума', 'обдума сво', 'сво жизн', 'жизн пришел', 'пришел том', 'том прежн', 'прежн успокоительн', 'успокоительн безнадежн', 'безнадежн заключен', 'заключен ем', 'ем начина', 'начина нич', 'нич над', 'над долж', 'долж дожива', 'дожива сво', 'сво жизн', 'жизн дел', 'дел зла', 'зла тревож', 'тревож нич', 'нич жел']
#
# Четырехиграммы (лемматизированные): ['край дорога стоять дуб', 'дорога стоять дуб вероятно', 'стоять дуб вероятно десять', 'дуб вероятно десять раз', 'вероятно десять раз старый', 'десять раз старый береза', 'раз старый береза составлять', 'старый береза составлять лес', 'береза составлять лес десять', 'составлять лес десять раз', 'лес десять раз толстый', 'десять раз толстый два', 'раз толстый два раз', 'толстый два раз высоко', 'два раз высоко каждый', 'раз высоко каждый береза', 'высоко каждый береза это', 'каждый береза это огромный', 'береза это огромный два', 'это огромный два обхват', 'огромный два обхват дуб', 'два обхват дуб обломать', 'обхват дуб обломать давно', 'дуб обломать давно видно', 'обломать давно видно сук', 'давно видно сук обломать', 'видно сук обломать кора', 'сук обломать кора зарастать', 'обломать кора зарастать старый', 'кора зарастать старый болячка', 'зарастать старый болячка огромный', 'старый болячка огромный свой', 'болячка огромный свой неуклюжий', 'огромный свой неуклюжий несимметричнорастопыривать', 'свой неуклюжий несимметричнорастопыривать корявый', 'неуклюжий несимметричнорастопыривать корявый рука', 'несимметричнорастопыривать корявый рука палец', 'корявый рука палец старый', 'рука палец старый сердитый', 'палец старый сердитый презрительный', 'старый сердитый презрительный урод', 'сердитый презрительный урод стоять', 'презрительный урод стоять улыбаться', 'урод стоять улыбаться береза', 'стоять улыбаться береза хотеть', 'улыбаться береза хотеть подчиняться', 'береза хотеть подчиняться обаяние', 'хотеть подчиняться обаяние весна', 'подчиняться обаяние весна хотеть', 'обаяние весна хотеть видеть', 'весна хотеть видеть весна', 'хотеть видеть весна солнце', 'видеть весна солнце весна', 'весна солнце весна любовь', 'солнце весна любовь счастие', 'весна любовь счастие будто', 'любовь счастие будто говорить', 'счастие будто говорить дуб', 'будто говорить дуб надоедать', 'говорить дуб надоедать вы', 'дуб надоедать вы тот', 'надоедать вы тот глупый', 'вы тот глупый бессмысленный', 'тот глупый бессмысленный обман', 'глупый бессмысленный обман один', 'бессмысленный обман один обман', 'обман один обман нет', 'один обман нет весна', 'обман нет весна солнце', 'нет весна солнце счастие', 'весна солнце счастие вон', 'солнце счастие вон смотреть', 'счастие вон смотреть сидеть', 'вон смотреть сидеть задавливать', 'смотреть сидеть задавливать мертвый', 'сидеть задавливать мертвый есть', 'задавливать мертвый есть одинакий', 'мертвый есть одинакий вон', 'есть одинакий вон я', 'одинакий вон я растопыривать', 'вон я растопыривать свой', 'я растопыривать свой обломать', 'растопыривать свой обломать обдирать', 'свой обломать обдирать палец', 'обломать обдирать палец вырастать', 'обдирать палец вырастать они', 'палец вырастать они спина', 'вырастать они спина бок', 'они спина бок вырастать', 'спина бок вырастать стоять', 'бок вырастать стоять верить', 'вырастать стоять верить ваш', 'стоять верить ваш надежда', 'верить ваш надежда обман', 'ваш надежда обман князь', 'надежда обман князь андрей', 'обман князь андрей несколько', 'князь андрей несколько раз', 'андрей несколько раз оглянуться', 'несколько раз оглянуться дуб', 'раз оглянуться дуб проезжать', 'оглянуться дуб проезжать лес', 'дуб проезжать лес будто', 'проезжать лес будто чегото', 'лес будто чегото ждать', 'будто чегото ждать он', 'чегото ждать он цветок', 'ждать он цветок трава', 'он цветок трава быть', 'цветок трава быть дуб', 'трава быть дуб хмуриться', 'быть дуб хмуриться неподвижно', 'дуб хмуриться неподвижно уродливый', 'хмуриться неподвижно уродливый упорно', 'неподвижно уродливый упорно стоять', 'уродливый упорно стоять посреди', 'упорно стоять посреди да', 'стоять посреди да правый', 'посреди да правый тысяча', 'да правый тысяча раз', 'правый тысяча раз правый', 'тысяча раз правый дуб', 'раз правый дуб думать', 'правый дуб думать князь', 'дуб думать князь андрей', 'думать князь андрей пускай', 'князь андрей пускай другой', 'андрей пускай другой мо ...
#
# Четырехиграммы (стемминговые): ['кра дорог стоя дуб', 'дорог стоя дуб вероятн', 'стоя дуб вероятн деся', 'дуб вероятн деся раз', 'вероятн деся раз старш', 'деся раз старш берез', 'раз старш берез составля', 'старш берез составля лес', 'берез составля лес деся', 'составля лес деся раз', 'лес деся раз толщ', 'деся раз толщ два', 'раз толщ два раз', 'толщ два раз выш', 'два раз выш кажд', 'раз выш кажд берез', 'выш кажд берез эт', 'кажд берез эт огромн', 'берез эт огромн два', 'эт огромн два обхват', 'огромн два обхват дуб', 'два обхват дуб облома', 'обхват дуб облома давн', 'дуб облома давн видн', 'облома давн видн сук', 'давн видн сук облома', 'видн сук облома кор', 'сук облома кор заросш', 'облома кор заросш стар', 'кор заросш стар болячк', 'заросш стар болячк огромн', 'стар болячк огромн сво', 'болячк огромн сво неуклюж', 'огромн сво неуклюж несимметричнорастопырен', 'сво неуклюж несимметричнорастопырен коряв', 'неуклюж несимметричнорастопырен коряв рук', 'несимметричнорастопырен коряв рук пальц', 'коряв рук пальц стар', 'рук пальц стар сердит', 'пальц стар сердит презрительн', 'стар сердит презрительн урод', 'сердит презрительн урод стоя', 'презрительн урод стоя улыба', 'урод стоя улыба берез', 'стоя улыба берез хотел', 'улыба берез хотел подчиня', 'берез хотел подчиня обаян', 'хотел подчиня обаян весн', 'подчиня обаян весн хотел', 'обаян весн хотел видет', 'весн хотел видет весн', 'хотел видет весн солнц', 'видет весн солнц весн', 'весн солнц весн любов', 'солнц весн любов счаст', 'весн любов счаст будт', 'любов счаст будт говор', 'счаст будт говор дуб', 'будт говор дуб надоест', 'говор дуб надоест вам', 'дуб надоест вам тот', 'надоест вам тот глуп', 'вам тот глуп бессмыслен', 'тот глуп бессмыслен обма', 'глуп бессмыслен обма одн', 'бессмыслен обма одн обма', 'обма одн обма нет', 'одн обма нет весн', 'обма нет весн солнц', 'нет весн солнц счаст', 'весн солнц счаст вон', 'солнц счаст вон смотр', 'счаст вон смотр сид', 'вон смотр сид задавлен', 'смотр сид задавлен мертв', 'сид задавлен мертв ел', 'задавлен мертв ел одинак', 'мертв ел одинак вон', 'ел одинак вон я', 'одинак вон я растопыр', 'вон я растопыр сво', 'я растопыр сво облома', 'растопыр сво облома ободра', 'сво облома ободра пальц', 'облома ободра пальц выросл', 'ободра пальц выросл он', 'пальц выросл он спин', 'выросл он спин бок', 'он спин бок выросл', 'спин бок выросл сто', 'бок выросл сто вер', 'выросл сто вер ваш', 'сто вер ваш надежд', 'вер ваш надежд обман', 'ваш надежд обман княз', 'надежд обман княз андр', 'обман княз андр нескольк', 'княз андр нескольк раз', 'андр нескольк раз оглянул', 'нескольк раз оглянул дуб', 'раз оглянул дуб проезж', 'оглянул дуб проезж лес', 'дуб проезж лес будт', 'проезж лес будт чегот', 'лес будт чегот ждал', 'будт чегот ждал нег', 'чегот ждал нег цвет', 'ждал нег цвет трав', 'нег цвет трав был', 'цвет трав был дуб', 'трав был дуб хмур', 'был дуб хмур неподвижн', 'дуб хмур неподвижн уродлив', 'хмур неподвижн уродлив упорн', 'неподвижн уродлив упорн стоя', 'уродлив упорн стоя посред', 'упорн стоя посред да', 'стоя посред да прав', 'посред да прав тысяч', 'да прав тысяч раз', 'прав тысяч раз прав', 'тысяч раз прав дуб', 'раз прав дуб дума', 'прав дуб дума княз', 'дуб дума княз андр', 'дума княз андр пуска', 'княз андр пуска друг', 'андр пуска друг молод', 'пуска друг молод внов', 'друг молод внов подда', 'молод внов подда обма', 'внов подда обма зна', 'подда обма зна жизн', 'обма зна жизн наш', 'зна жизн наш жизн', 'жизн наш жизн конч', 'наш жизн конч цел', 'жизн конч цел нов', 'конч цел нов ряд', 'цел нов ряд мысл', 'нов ряд мысл безнадежн', 'ряд мысл безнадежн грустноприятн', 'мысл безнадежн грустноприятн связ', 'безнадежн грустноприятн связ эт', 'грустноприятн связ эт дуб', 'связ эт дуб возник', 'эт дуб возник душ', 'дуб возник душ княз', 'возник душ княз андре', 'душ княз андре во', 'княз андре во врем', 'андре во врем эт', 'во врем эт путешеств', 'врем эт путешеств будт', 'эт путешеств будт внов', 'путешеств будт внов обдума', ' ...
